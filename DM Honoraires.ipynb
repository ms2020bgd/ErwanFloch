# %% [markdown]
# # **Médecins par spécialité**

# %% [markdown]
# **Ouverture du fichier Excel**

# %%
import pandas as pd
import xlrd

# %%
df = pd.read_excel(r"D:\COURS_TELECOM_PARIS\7. Python\Cours 6\honoraires.xls", sheet_name='Specialistes')
df.describe(include = 'all')
# Out:
#                   Spécialistes        DEPARTEMENT  NOMBRE D'APE  \
# count                     5616               5616   5616.000000
# unique                      54                104           NaN
# top     78- Médecine génétique  22- Côtes-d'Armor           NaN
# freq                       104                 54           NaN
# mean                       NaN                NaN    100.020833
# std                        NaN                NaN   1804.636935
# min                        NaN                NaN      0.000000
# 25%                        NaN                NaN      0.000000
# 50%                        NaN                NaN      3.000000
# 75%                        NaN                NaN     14.000000
# max                        NaN                NaN  87084.000000
#
#        HONORAIRES SANS DEPASSEMENT (Euros) DEPASSEMENTS (Euros)  \
# count                                 5616                 5616
# unique                                1505                 1484
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5616 entries, 0 to 5615
# Data columns (total 11 columns):
# Spécialistes                                5616 non-null object
# DEPARTEMENT                                 5616 non-null object
# NOMBRE D'APE                                5616 non-null int64
# HONORAIRES SANS DEPASSEMENT (Euros)         5616 non-null object
# DEPASSEMENTS (Euros)                        5616 non-null object
# FRAIS DE DEPLACEMENTS (Euros)               5616 non-null object
# TOTAL DES HONORAIRES (Euros)                5616 non-null object
# HONORAIRES SANS DEPASSEMENT /APE (Euros)    5616 non-null object
# DEPASSEMENTS /APE (Euros)                   5616 non-null object
# FRAIS DE DEPLACEMENTS /APE (Euros)          5616 non-null object
# HONORAIRES /APE (Euros)                     5616 non-null object
# dtypes: int64(1), object(10)
# memory usage: 482.7+ KB

# %% [markdown]
# **Cleaning the dataset**

# %%
df.dropna()
# Out:
#                                  Spécialistes                  DEPARTEMENT  \
# 0     02- Anesthésie-réanimation chirurgicale                      01- Ain
# 1     02- Anesthésie-réanimation chirurgicale                    02- Aisne
# 2     02- Anesthésie-réanimation chirurgicale                   03- Allier
# 3     02- Anesthésie-réanimation chirurgicale       04- Alpes-Hte-Provence
# 4     02- Anesthésie-réanimation chirurgicale             05- Hautes-Alpes
# 5     02- Anesthésie-réanimation chirurgicale          06- Alpes-Maritimes
# 6     02- Anesthésie-réanimation chirurgicale                  07- Ardèche
# 7     02- Anesthésie-réanimation chirurgicale                 08- Ardennes
# 8     02- Anesthésie-réanimation chirurgicale                   09- Ariège
# 9     02- Anesthésie-réanimation chirurgicale                     10- Aube
# 10    02- Anesthésie-réanimation chirurgicale                     11- Aude
# ...

# %%
# Removal of 'nc' rows
data = df[df['DEPASSEMENTS (Euros)'] != 'nc']
pd.to_numeric(data['DEPASSEMENTS (Euros)'])
# Out:
# 0       1.902299e+06
# 1       3.826841e+05
# 2       5.283503e+05
# 5       9.207397e+06
# 6       7.264929e+05
# 8       0.000000e+00
# 10      3.381461e+05
# 12      3.026177e+06
# 13      2.186294e+05
# 15      9.895426e+05
# 16      1.054550e+06
# 21      2.631726e+06
# 22      6.449146e+04
# 25      2.739451e+05
# 26      1.244213e+06
# 29      6.673625e+04
# 30      2.265626e+06
# 31      1.916363e+06
# 33      1.432565e+07
# 34      4.370311e+06
# 35      3.196264e+05
# 37      1.796788e+06
# 38      4.675350e+06
# 42      2.220644e+06
# 44      1.600830e+06
# 45      3.758990e+06
# 47      1.718750e+05
# 48      0.000000e+00
# 49      2.242352e+06
# 50      5.363776e+04
#             ...
# 5586    3.666115e+07
# 5587    4.466052e+08
# 5588    2.675640e+07
# 5589    4.579905e+07
# 5590    8.947554e+07
# 5591    4.370194e+06
# 5592    1.346010e+07
# 5593    3.067788e+06
# 5594    4.808373e+06
# 5595    3.607927e+07
# 5596    2.125627e+07
# 5597    7.456141e+06
# ...

# %% [markdown]
# **Dépassement d´honoraires par sécialité pour la France entière**

# %%
depassements_France = data[data['DEPARTEMENT'].str.find('TOTAL France ENTIERE') != -1]

# %%
depassements_France
# Out:
#                                            Spécialistes           DEPARTEMENT  \
# 103             02- Anesthésie-réanimation chirurgicale  TOTAL France ENTIERE
# 207                            20- Réanimation médicale  TOTAL France ENTIERE
# 311              TOTAL ANESTHESIE REANIMATION  (02, 20)  TOTAL France ENTIERE
# 415                    03- Pathologie cardio-vasculaire  TOTAL France ENTIERE
# 519                             43- Chirurgie infantile  TOTAL France ENTIERE
# 623                       44- Chirurgie maxillo-faciale  TOTAL France ENTIERE
# 727   46- Chirurgie plastique reconstructrice et est...  TOTAL France ENTIERE
# 831       47- Chirurgie thoracique et cardio-vasculaire  TOTAL France ENTIERE
# 935                            48- Chirurgie vasculaire  TOTAL France ENTIERE
# 1039               49- Chirurgie viscérale et digestive  TOTAL France ENTIERE
# 1143                             04- Chirurgie générale  TOTAL France ENTIERE
# ...

# %% [markdown]
# **Pivot pour la France entière**

# %%
# The column 'Depassements (Euros)' was not recognised
for col in data.columns: 
    print(col)
# Out:
# Spécialistes
# DEPARTEMENT
# NOMBRE D'APE
# HONORAIRES SANS DEPASSEMENT (Euros)
# DEPASSEMENTS (Euros)
# FRAIS DE DEPLACEMENTS (Euros)
# TOTAL DES HONORAIRES (Euros)
# HONORAIRES SANS DEPASSEMENT /APE (Euros)
# DEPASSEMENTS /APE (Euros)
# FRAIS DE DEPLACEMENTS /APE (Euros)
# HONORAIRES /APE (Euros)

# %%
depassements_France.pivot('Spécialistes', 'DEPARTEMENT', 'DEPASSEMENTS (Euros)')
# Out:
# DEPARTEMENT                                        TOTAL France ENTIERE
# Spécialistes
# 02- Anesthésie-réanimation chirurgicale                     2.43303e+08
# 03- Pathologie cardio-vasculaire                            4.24447e+07
# 04- Chirurgie générale                                        7.077e+07
# 05- Dermato-vénéréologie                                    7.09644e+07
# 06- Radiodiagnostic et imagerie médicale                    1.76405e+08
# 07- Gynécologie obstétrique                                 1.96791e+08
# 08- Gastro-entérologie et hépatologie                       5.29775e+07
# 09- Médecine interne                                        3.91397e+06
# 10- Neurochirurgie                                           3.0404e+07
# 11- Oto-rhino-laryngologie                                  8.46814e+07
# 12- Pédiatrie                                               5.02317e+07
# 13- Pneumologie                                             7.58207e+06
# ...

# %% [markdown]
# **Dépassement d´honoraires par sécialité par département**

# %%
depassements_Departements = data[data['DEPARTEMENT'].str.find('TOTAL France ENTIERE') == -1]

# %%
depassements_Departements
# Out:
#                                  Spécialistes                  DEPARTEMENT  \
# 0     02- Anesthésie-réanimation chirurgicale                      01- Ain
# 1     02- Anesthésie-réanimation chirurgicale                    02- Aisne
# 2     02- Anesthésie-réanimation chirurgicale                   03- Allier
# 5     02- Anesthésie-réanimation chirurgicale          06- Alpes-Maritimes
# 6     02- Anesthésie-réanimation chirurgicale                  07- Ardèche
# 8     02- Anesthésie-réanimation chirurgicale                   09- Ariège
# 10    02- Anesthésie-réanimation chirurgicale                     11- Aude
# 12    02- Anesthésie-réanimation chirurgicale         13- Bouches-du-Rhône
# 13    02- Anesthésie-réanimation chirurgicale                 14- Calvados
# 15    02- Anesthésie-réanimation chirurgicale                 16- Charente
# 16    02- Anesthésie-réanimation chirurgicale        17- Charente-Maritime
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3319 entries, 0 to 5615
# Data columns (total 11 columns):
# Spécialistes                                3319 non-null object
# DEPARTEMENT                                 3319 non-null object
# NOMBRE D'APE                                3319 non-null int64
# HONORAIRES SANS DEPASSEMENT (Euros)         3319 non-null object
# DEPASSEMENTS (Euros)                        3319 non-null object
# FRAIS DE DEPLACEMENTS (Euros)               3319 non-null object
# TOTAL DES HONORAIRES (Euros)                3319 non-null object
# HONORAIRES SANS DEPASSEMENT /APE (Euros)    3319 non-null object
# DEPASSEMENTS /APE (Euros)                   3319 non-null object
# FRAIS DE DEPLACEMENTS /APE (Euros)          3319 non-null object
# HONORAIRES /APE (Euros)                     3319 non-null object
# dtypes: int64(1), object(10)
# memory usage: 311.2+ KB

# %%
depassements_Departements.pivot('DEPARTEMENT', 'Spécialistes', 'DEPASSEMENTS (Euros)')
# Out:
# Spécialistes                02- Anesthésie-réanimation chirurgicale  \
# DEPARTEMENT
# 01- Ain                                                  1.9023e+06
# 02- Aisne                                                    382684
# 03- Allier                                                   528350
# 04- Alpes-Hte-Provence                                          NaN
# 05- Hautes-Alpes                                                NaN
# 06- Alpes-Maritimes                                      9.2074e+06
# 07- Ardèche                                                  726493
# 08- Ardennes                                                    NaN
# 09- Ariège                                                        0
# 10- Aube                                                        NaN
# 11- Aude                                                     338146
# 12- Aveyron                                                     NaN
# 13- Bouches-du-Rhône                                    3.02618e+06
# ...
